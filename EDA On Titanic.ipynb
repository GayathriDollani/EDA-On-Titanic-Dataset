# %% [markdown]
# # **EDA ON Titanic Dataset**

# %% [raw]
# The Titanic was a British Passenger liner that sank in the North Atlantic Ocean in the early morning hours of 15 April 1912, after it collided with an iceberg during its maiden voyage from Southampton to New York City. There were an estimated 2,224 passengers and crew aboard the ship and more than 1,500 died.

# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Loading Dataset**

# %%
Titanic=pd.read_csv(r"C:\Users\gayat\Downloads\titanic.csv")

# %% [raw]
# * Survival - Survival(0 = No; 1= Yes). Not included in test.csv file.
# * Pclass - Passenger Class(1 = 1st; 2 = 2nd; 3 = 3rd)
# * Name - Name
# * Sex - Sex
# * Age - Age
# * Sisp - Number of Siblings/Spouses Abroad
# * Parch - Number of Parents/Children Abroad
# * Ticket - Ticket Number
# * Fare - Passenger Fare
# * Cabin - Cabin
# * Embarked - Port of Embarkation(C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
Titanic
# Out:
#      PassengerId  Survival  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
cols = Titanic.columns
cols
# Out:
# Index(['PassengerId', 'Survival', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
Titanic.describe()
# Out:
#        PassengerId    Survival      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Titanic.shape
# Out:
# (891, 12)

# %%
Titanic.head()
# Out:
#    PassengerId  Survival  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survival     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Visualizing missing data using heatmap

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survival         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(Titanic.isnull(), yticklabels= False)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Cleaning and Pre-processing

# %% [markdown]
# ### Filling missing 'Age' with median

# %%
Titanic['Age'] = Titanic['Age'].fillna(Titanic['Age'].median())

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survival         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Filling missing 'Embarked' with mode

# %%
Titanic['Embarked'] = Titanic['Embarked'].fillna(Titanic['Embarked'].mode()[0])

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survival         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# ### Dropped Cabin due to Excess missingness

# %%
Titanic.drop(columns=['Cabin'], inplace=True)

# %%
Titanic.isnull().sum()
# Out:
# PassengerId    0
# Survival       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# sns.set_style("whitegrid")
# sns.heatmap(df.isnull(),yticklabels=False)

# %% [markdown]
# ### Checking for duplicate rows

# %%
Titanic.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### **Univariate Analysis**

# %%
print(list(cols))
# Out:
# ['PassengerId', 'Survival', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
fig, ax = plt.subplots(3, 3, figsize=(16, 16))

sns.countplot(x='Survival', data=Titanic, ax=ax[0][0])
sns.countplot(x='Pclass', data=Titanic, ax=ax[0][1])
sns.countplot(x='Sex', data=Titanic, ax=ax[0][2])
sns.countplot(x='SibSp', data=Titanic, ax=ax[1][0])
sns.countplot(x='Parch', data=Titanic, ax=ax[1][1])
sns.countplot(x='Embarked', data=Titanic, ax=ax[1][2])

sns.histplot(Titanic['Fare'], kde=True, ax=ax[2][1])
sns.histplot(Titanic['Age'], kde=True, ax=ax[2][2])

# Leave the unused plots empty
ax[2][0].axis('off')  # Optional: Hide the unused subplot

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Survival**

# %%
Titanic['Survival'].value_counts()
# Out:
# Survival
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.set_style=("whitegrid")
sns.countplot(x="Survival",data=Titanic)
plt.title('Titanic Survival Plot')
plt.show()

# %%
Titanic['Survival'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
Titanic['Survival'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
survival_rate = round(Titanic['Survival'].value_counts(normalize=True) * 100,2)
print(survival_rate)
# Out:
# Survival
# 0    61.62
# 1    38.38
# Name: proportion, dtype: float64

# %%
Titanic['Survival'].value_counts().plot.pie(autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### **PClass**

# %%
Titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
Titanic.groupby(['Pclass', 'Survival'])['Survival'].count()
# Out:
# Pclass  Survival
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survival, dtype: int64

# %%
sns.countplot(x='Pclass',data=Titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# # **Bivariate Analysis**

# %%
sns.countplot(x= 'Pclass', data =Titanic, hue = 'Survival')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
Titanic['Pclass'].value_counts().plot.pie(autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x='Pclass', y='Survival', data=Titanic)
plt.title('Survival Rate by Passenger Class(Pclass)')
plt.show()

# %% [markdown]
# ### **Gender**

# %%
Titanic['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ### Survival Rate by gender

# %%
round(Titanic.groupby('Sex')['Survival'].mean()*100)
# Out:
# Sex
# female    74.0
# male      19.0
# Name: Survival, dtype: float64

# %%
sns.countplot(x='Sex', data=Titanic)
plt.title('Gender Distribution')
plt.show()

# %%
sns.countplot(x='Sex', data = Titanic, hue = 'Survival')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
Titanic['Sex'].value_counts().plot.pie(autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### **Age**

# %%
sns.histplot(Titanic['Age'], kde=True, bins=30)
plt.title('Age Distribution')
plt.show()

# %%
sns.histplot(data=Titanic, x='Age', hue='Survival', bins=30)
plt.title('Age Distribution by Survival')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Survival')

# %%
sns.histplot(Titanic[Titanic['Survival']==1]['Age'], bins=20, kde=True, label='Survived', color='green')
sns.histplot(Titanic[Titanic['Survival']==0]['Age'], bins=20, kde=True, label='Not Survived', color='red')
plt.legend()
plt.title('Age Distribution by Survival')
plt.show()

# %% [markdown]
# ### **Embarked**

# %%
sns.countplot(x='Embarked', data=Titanic)
plt.title('Embarked Distribution')
plt.show()

# %% [markdown]
# ## **Feature Engineering**

# %% [markdown]
# ### Create FamilySize

# %%
Titanic['FamilySize'] = Titanic['SibSp'] + Titanic['Parch'] + 1

# %%
Titanic['FamilySize']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: FamilySize, Length: 891, dtype: int64

# %% [markdown]
# ### Survival by FamilySize

# %%
sns.countplot(x='Survival', hue='FamilySize', data=Titanic)
plt.title('Survival Rate by Family Size')
plt.show()

# %% [markdown]
# ### Create a 'IsAlone' feature: 1 if Alone, 0 if with family

# %%
Titanic['IsAlone'] = np.where(Titanic['FamilySize'] == 1, 1, 0)

# %%
Titanic
# Out:
#      PassengerId  Survival  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### **Final Insights**

# %%
print("\nKey Insights:")
print("- Females had a higher chance of survival compared to males.")
print("- Passengers in 1st class had higher survival rates.")
print("- Younger passengers, especially children, had better survival rates.")
print("- Passengers traveling alone were less likely to survive.")
print("- Ticket fare and family size showed some influence on survival.")
# Out:
# Key Insights:
# - Females had a higher chance of survival compared to males.
# - Passengers in 1st class had higher survival rates.
# - Younger passengers, especially children, had better survival rates.
# - Passengers traveling alone were less likely to survive.
# - Ticket fare and family size showed some influence on survival.

# %% [markdown]
# ### Displaying the cleaned and processed dataset

# %%
Titanic.head()
# Out:
#    PassengerId  Survival  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  FamilySize  IsAlone
# 0      0         A/5 21171   7.2500        S           2        0
# 1      0          PC 17599  71.2833        C           2        0
# 2      0  STON/O2. 3101282   7.9250        S           1        1
# ...
